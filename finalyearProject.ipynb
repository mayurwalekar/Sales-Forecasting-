# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %%
import pandas as pd
data= pd.read_csv("adidas_revenue1.csv")
data.head(69)
# Out:
#       date  Revenue     US GDP  Europe GDP   CHN GDP US  Price Index    NIKE
# 0   2000Q1     1517  12359.095   1728.2440   257.649148        246.5  2161.6
# 1   2000Q2     1248  12592.530   1749.6000   290.437535        326.4  2272.7
# 2   2000Q3     1677  12607.676   1769.2586   310.550979        322.5  2636.7
# 3   2000Q4     1393  12679.338   1789.2533   352.695291        321.0  2198.7
# 4   2001Q1     1558  12643.283   1819.1398   290.974546        329.4  2170.1
# ..     ...      ...        ...         ...          ...          ...     ...
# 64  2016Q1     4769  16571.573   2672.9105  2498.306867        329.4  8032.0
# 65  2016Q2     4199  16663.516   2683.9678  2720.204681        324.1  8244.0
# 66  2016Q3     5413  16778.148   2699.5255  2856.350444        322.4  9061.0
# 67  2016Q4     4687  16851.420   2725.4219  3040.101873        325.4  8180.0
# 68  2017Q1     5671  16903.240   2745.1033  2622.014221        344.6  8432.0
#
# [69 rows x 7 columns]

# %%
data.describe()
# Out:
#            Revenue        US GDP   Europe GDP   CHN GDP US  Price Index  \
# count    69.000000     69.000000    69.000000    69.000000    69.000000
# mean   2747.565217  14629.801304  2275.453749  1350.983874   345.389855
# std    1112.644908   1254.572388   282.574293   922.619704    68.319408
# min    1078.000000  12359.095000  1728.244000   257.649148   246.500000
# 25%    1674.000000  13706.247000  2031.764800   480.469269   305.600000
# 50%    2577.000000  14726.022000  2349.078300  1148.386815   327.100000
# 75%    3480.000000  15384.254000  2461.767500  2198.146297   354.000000
# max    5671.000000  16903.240000  2745.103300  3040.101873   655.800000
#
#               NIKE
# count    69.000000
# mean   4851.402896
# std    1951.847773
# min    2161.600000
# 25%    3148.300000
# 50%    4590.100000
# 75%    6236.000000
# max    9061.000000

# %%
data.shape
# Out:
# (69, 7)

# %%
data.dtypes
# Out:
# date            object
# Revenue          int64
# US GDP         float64
# Europe GDP     float64
# CHN GDP US     float64
# Price Index    float64
# NIKE           float64
# dtype: object

# %%
data.isna().sum()  ##Checking missing values in data
# Out:
# date           0
# Revenue        0
# US GDP         0
# Europe GDP     0
# CHN GDP US     0
# Price Index    0
# NIKE           0
# dtype: int64

# %%
data['date'] = pd.to_datetime(data['date'], infer_datetime_format=True)
indexedDataset = data.set_index(['date'])
df = pd.DataFrame(data, columns=['Revenue', 'date'])

# %%
import matplotlib.pyplot as plt
df.plot(x='date', y='Revenue', kind='line') 
plt.show()

# %% [markdown]
# Sorting data with respect to date

# %%
df.set_index('date', inplace=True)

# %%
#sorting data date wise
df = df.sort_values(['date'])

# %%
df.shape
# Out:
# (69, 1)

# %%
df.head(70)
# Out:
#             Revenue
# date
# 2000-01-01     1517
# 2000-04-01     1248
# 2000-07-01     1677
# 2000-10-01     1393
# 2001-01-01     1558
# ...             ...
# 2016-01-01     4769
# 2016-04-01     4199
# 2016-07-01     5413
# 2016-10-01     4687
# 2017-01-01     5671
#
# [69 rows x 1 columns]

# %%
df.loc['2000-01-01':]
df.plot()
# Out:
# <AxesSubplot:xlabel='date'>
